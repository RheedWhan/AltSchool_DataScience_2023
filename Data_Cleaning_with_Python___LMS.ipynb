# %% [markdown]
# <a href="https://colab.research.google.com/github/RheedWhan/AltSchool_DataScience_2023/blob/main/Data_Cleaning_with_Python___LMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Extracting Dataset

# %%
# import libraries

import pandas as pd

# %%
# create a dataset

url_link1 = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'
company_data = pd.read_html(url_link1)

# %%
type(company_data)
# Out:
# list

# %%
company_data = company_data[0]

# %%
type(company_data)
# Out:
# pandas.core.frame.DataFrame

# %%
company_data.head()
# Out:
#   Rank                             Name     Industry      Revenue  \
#   Rank                             Name     Industry USD millions
# 0    1                          Walmart       Retail     $611,289
# 1    2                     Saudi Aramco  Oil and gas     $603,651
# 2    3  State Grid Corporation of China  Electricity     $530,009
# 3    4                           Amazon       Retail     $513,983
# 4    5                            Vitol  Commodities     $505,000
#
#         Profit Employees Headquarters[note 1] State-owned               Ref.  \
#   USD millions Employees Headquarters[note 1] State-owned Revenue per worker
# 0      $11,680   2100000        United States         NaN                [1]
# 1     $159,069     70496         Saudi Arabia         NaN                [4]
# 2       $8,192    870287                China         NaN                [5]
# 3      −$2,722   1541000        United States         NaN                [6]
# ...

# %%
company_data.columns
# Out:
# MultiIndex([(                'Rank',                 'Rank'),
#             (                'Name',                 'Name'),
#             (            'Industry',             'Industry'),
#             (             'Revenue',         'USD millions'),
#             (              'Profit',         'USD millions'),
#             (           'Employees',            'Employees'),
#             ('Headquarters[note 1]', 'Headquarters[note 1]'),
#             (         'State-owned',          'State-owned'),
#             (                'Ref.',   'Revenue per worker'),
#             (  'Unnamed: 9_level_0',   'Revenue per worker')],
#            )

# %%
company_data.columns = company_data.columns.get_level_values(0)

# %%
company_data.columns
# Out:
# Index(['Rank', 'Name', 'Industry', 'Revenue', 'Profit', 'Employees',
#        'Headquarters[note 1]', 'State-owned', 'Ref.', 'Unnamed: 9_level_0'],
#       dtype='object')

# %%
company_data.head()
# Out:
#    Rank                             Name     Industry   Revenue    Profit  \
# 0     1                          Walmart       Retail  $611,289   $11,680
# 1     2                     Saudi Aramco  Oil and gas  $603,651  $159,069
# 2     3  State Grid Corporation of China  Electricity  $530,009    $8,192
# 3     4                           Amazon       Retail  $513,983   −$2,722
# 4     5                            Vitol  Commodities  $505,000   $15,000
#
#    Employees Headquarters[note 1]  State-owned    Ref. Unnamed: 9_level_0
# 0    2100000        United States          NaN     [1]         291.090,00
# 1      70496         Saudi Arabia          NaN     [4]       8.562.911,37
# 2     870287                China          NaN     [5]         609.004,85
# 3    1541000        United States          NaN     [6]         333.538,61
# 4       1560          Switzerland          NaN  [7][8]     323.717.948,72

# %%
# dropping the ref column

company_data.drop(columns=['Ref.', 'State-owned'], inplace=True)

# %% [markdown]
# ### Renaming the columns

# %%
company_data.columns
# Out:
# Index(['Rank', 'Name', 'Industry', 'Revenue', 'Profit', 'Employees',
#        'Headquarters[note 1]', 'Unnamed: 9_level_0'],
#       dtype='object')

# %%
company_data.rename(columns =
                    {'Rank': 'Ranking',
                     'Name': 'Company Name',
                     'Revenue': 'Revenue(USD millions)',
                     'Profit': 'Profit(USD millions)',
                     'Headquarters[note 1]': 'Headquarters',
                    'Unnamed: 9_level_0': 'Revenue per worker'}, inplace=True
                    )

# %%
company_data.head()
# Out:
#    Ranking                     Company Name     Industry  \
# 0        1                          Walmart       Retail
# 1        2                     Saudi Aramco  Oil and gas
# 2        3  State Grid Corporation of China  Electricity
# 3        4                           Amazon       Retail
# 4        5                            Vitol  Commodities
#
#   Revenue(USD millions) Profit(USD millions)  Employees   Headquarters  \
# 0              $611,289              $11,680    2100000  United States
# 1              $603,651             $159,069      70496   Saudi Arabia
# 2              $530,009               $8,192     870287          China
# 3              $513,983              −$2,722    1541000  United States
# 4              $505,000              $15,000       1560    Switzerland
#
#   Revenue per worker
# 0         291.090,00
# 1       8.562.911,37
# 2         609.004,85
# 3         333.538,61
# 4     323.717.948,72

# %%
# remove the dollar sign and comma from revenue and change it to float
company_data['Revenue(USD millions)'] = company_data['Revenue(USD millions)'].str.replace('[\$,]', '', regex=True).astype(float)

# remove the dollar sign and comma from profit
company_data['Profit(USD millions)'] = company_data['Profit(USD millions)'].str.replace('[^\d−]', '', regex=True)

# remove the dollar sign and comma from revenue per worker and change it to float
company_data['Revenue per worker'] = company_data['Revenue per worker'].str.replace('[\.,]', '', regex=True).astype(int)

# %%
# change the minus sign to a standard minus sign
company_data['Profit(USD millions)'] = company_data['Profit(USD millions)'].str.replace('−', '-', regex=True)

# change the 'Profit(USD millions) to numeric values while omitting the empty column
company_data['Profit(USD millions)'] = pd.to_numeric(company_data['Profit(USD millions)'], errors='coerce')

# %%
company_data.tail()
# Out:
#     Ranking         Company Name      Industry  Revenue(USD millions)  \
# 45       46                Baowu         Steel               161698.0
# 46       47       Schwarz Gruppe        Retail               159800.0
# 47       48     Mitsubishi Group  Conglomerate               159371.0
# 48       49   Ford Motor Company    Automotive               158057.0
# 49       50  Mercedes-Benz Group    Automotive               157403.0
#
#     Profit(USD millions)  Employees   Headquarters  Revenue per worker
# 45                2493.0     245675          China            65817849
# 46                   NaN     575000        Germany            27791304
# 47                8723.0      79706          Japan           199948561
# 48               -1981.0     173000  United States            91362428
# 49               15252.0     168797        Germany            93249880

# %% [markdown]
# ### Summary of the data

# %%
company_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ranking                50 non-null     int64
#  1   Company Name           50 non-null     object
#  2   Industry               50 non-null     object
#  3   Revenue(USD millions)  50 non-null     float64
#  4   Profit(USD millions)   48 non-null     float64
#  5   Employees              50 non-null     int64
#  6   Headquarters           50 non-null     object
#  7   Revenue per worker     50 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 3.2+ KB

# %%
company_data.describe()
# Out:
#         Ranking  Revenue(USD millions)  Profit(USD millions)     Employees  \
# count  50.00000              50.000000             48.000000  5.000000e+01
# mean   25.50000          274052.340000          20835.479167  3.200794e+05
# std    14.57738          124926.376138          29639.524909  3.940428e+05
# min     1.00000          157403.000000          -2722.000000  1.560000e+03
# 25%    13.25000          176779.500000           4001.750000  7.029725e+04
# 50%    25.50000          236358.000000          12067.000000  2.208800e+05
# 75%    37.75000          315328.250000          20221.500000  3.828730e+05
# max    50.00000          611289.000000         159069.000000  2.100000e+06
#
#        Revenue per worker
# count        5.000000e+01
# mean         1.021955e+09
# std          4.581168e+09
# min          2.779130e+07
# 25%          5.612570e+07
# 50%          9.053868e+07
# 75%          3.875228e+08
# max          3.237179e+10

# %% [markdown]
# ### Explanatory Data Analysis

# %%
company_data.head()
# Out:
#    Ranking                     Company Name     Industry  \
# 0        1                          Walmart       Retail
# 1        2                     Saudi Aramco  Oil and gas
# 2        3  State Grid Corporation of China  Electricity
# 3        4                           Amazon       Retail
# 4        5                            Vitol  Commodities
#
#    Revenue(USD millions)  Profit(USD millions)  Employees   Headquarters  \
# 0               611289.0               11680.0    2100000  United States
# 1               603651.0              159069.0      70496   Saudi Arabia
# 2               530009.0                8192.0     870287          China
# 3               513983.0               -2722.0    1541000  United States
# 4               505000.0               15000.0       1560    Switzerland
#
#    Revenue per worker
# 0            29109000
# 1           856291137
# 2            60900485
# 3            33353861
# 4         32371794872

# %%
 # Check the company with the highest profit

 company_data['Profit(USD millions)'].sort_values(ascending=False)
# Out:
# 1     159069.0
# 8      99803.0
# 30     72738.0
# 17     59972.0
# 7      55740.0
# 28     53589.0
# 29     48145.0
# 25     42398.0
# 32     38524.0
# 23     35465.0
# 5      21080.0
# 20     20526.0
# 10     20120.0
# 9      20120.0
# 19     18110.0
# 31     17669.0
# 41     17641.0
# 21     17320.0
# 43     16988.0
# 49     15252.0
# 15     15233.0
# 4      15000.0
# 36     14516.0
# 33     12454.0
# 0      11680.0
# 40     11528.0
# 37     11024.0
# 6       9657.0
# 47      8723.0
# 2       8192.0
# 12      6994.0
# 35      6668.0
# 26      5844.0
# 27      4751.0
# 13      4234.0
# 11      4149.0
# 18      3560.0
# 45      2493.0
# 39      2035.0
# 44      1800.0
# 24      1699.0
# 38         1.0
# 34      -933.0
# 48     -1981.0
# 16     -1996.0
# 14     -2282.0
# 22     -2487.0
# 3      -2722.0
# 42         NaN
# 46         NaN
# Name: Profit(USD millions), dtype: float64
