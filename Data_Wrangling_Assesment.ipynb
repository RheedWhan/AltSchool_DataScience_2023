# %% [markdown]
# <a href="https://colab.research.google.com/github/RheedWhan/AltSchool_DataScience_2023/blob/main/Data_Wrangling_Assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Using the Chicago Crime Dataset(any of the 3 sheets you choose), perfrom the following data preparation steps:
# 1. Use a funtion to Drop redundant columns (a redundant colum is one that gives infromation that another column already explains: eg ID and Case number)
# 2. Use functions to create new columns for Months, Day, Season.
# 3. Use subsetting and grouping to show how the frequency of crime is distributed within Months, Days, Seasons with the most crime record and what crimes are highest and lowest?
# 4.  According to location description, where does crime hapen the most?
# 5.  Did the Types of crime change as years go by? if yes/no. let the data show the insight.

# %%
- Submission Deadline: 02/11/2024
- Submission link (https://forms.gle/NSVRvGGir88wHsn59)
# Out:
#   File "<ipython-input-51-6dac2e7a47a6>", line 1
#     - Submission Deadline: 02/11/2024
#                            ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chicago_df = pd.read_csv('/content/chicago3.csv') # Import data

# %%
chicago_df.head() # Check the first 5 rows
# Out:
#    Unnamed: 0       ID Case Number                    Date  \
# 0      201000  3653721    HK742237  10/25/2004 12:00:00 AM
# 1      201001  3105528    HJ837008  12/24/2003 08:30:00 PM
# 2      201002  3761615    HL132238  01/18/2005 11:11:31 PM
# 3      201003  3613882    HK707251  10/24/2004 03:05:00 PM
# 4      201004  1504341     G247242  04/30/2001 05:52:55 PM
#
#                    Block  IUCR     Primary Type  \
# 0      008XX N HOMAN AVE  2825    OTHER OFFENSE
# 1      061XX N AVERS AVE  0610         BURGLARY
# 2  045XX N MILWAUKEE AVE  0496          BATTERY
# 3    012XX W BELMONT AVE  1310  CRIMINAL DAMAGE
# 4          027XX W 23 PL  0460          BATTERY
#
#                                        Description Location Description  \
# 0                          HARASSMENT BY TELEPHONE            RESIDENCE
# 1                                   FORCIBLE ENTRY            RESIDENCE
# 2  AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST            RESIDENCE
# ...

# %%
chicago_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Case Number', 'Date', 'Block', 'IUCR',
#        'Primary Type', 'Description', 'Location Description', 'Arrest',
#        'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code',
#        'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# Use a funtion to Drop redundant columns (a redundant colum is one that gives infromation that another column already explains: eg ID and Case number)

# %%
# Columns like 'Unnamed: 0', 'Case Number' and location can be dropped
def drop_col(df, columns):
    return df.drop(columns=columns, inplace=True)

# %%
columns_to_drop = ['Unnamed: 0', 'Case Number', 'Latitude', 'Longitude']

drop_col(chicago_df, columns_to_drop)

# %%
chicago_df.head()
# Out:
#         ID                    Date                  Block  IUCR  \
# 0  3653721  10/25/2004 12:00:00 AM      008XX N HOMAN AVE  2825
# 1  3105528  12/24/2003 08:30:00 PM      061XX N AVERS AVE  0610
# 2  3761615  01/18/2005 11:11:31 PM  045XX N MILWAUKEE AVE  0496
# 3  3613882  10/24/2004 03:05:00 PM    012XX W BELMONT AVE  1310
# 4  1504341  04/30/2001 05:52:55 PM          027XX W 23 PL  0460
#
#       Primary Type                                      Description  \
# 0    OTHER OFFENSE                          HARASSMENT BY TELEPHONE
# 1         BURGLARY                                   FORCIBLE ENTRY
# 2          BATTERY  AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST
# 3  CRIMINAL DAMAGE                                      TO PROPERTY
# 4          BATTERY                                           SIMPLE
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# 0            RESIDENCE   False     False  1121      11.0  27.0
# ...

# %% [markdown]
# Use functions to create new columns for Months, Day, Season.

# %%
def month_day_season(df, date_column):
    df[date_column] = pd.to_datetime(df[date_column])

    # Extract month, day, and season
    df['Month'] = df[date_column].dt.month
    df['Day'] = df[date_column].dt.day

    # Define a function to get season based on month
    def season(month):
        if month in [12, 1, 2]:
            return 'Winter'
        elif month in [3, 4, 5]:
            return 'Spring'
        elif month in [6, 7, 8]:
            return 'Summer'
        else:
            return 'Fall'

    df['Season'] = df['Month'].apply(season)
    return df.head()

# %%
month_day_season(chicago_df, 'Date')
# Out:
#         ID                Date                  Block  IUCR     Primary Type  \
# 0  3653721 2004-10-25 00:00:00      008XX N HOMAN AVE  2825    OTHER OFFENSE
# 1  3105528 2003-12-24 20:30:00      061XX N AVERS AVE  0610         BURGLARY
# 2  3761615 2005-01-18 23:11:31  045XX N MILWAUKEE AVE  0496          BATTERY
# 3  3613882 2004-10-24 15:05:00    012XX W BELMONT AVE  1310  CRIMINAL DAMAGE
# 4  1504341 2001-04-30 17:52:55          027XX W 23 PL  0460          BATTERY
#
#                                        Description Location Description  \
# 0                          HARASSMENT BY TELEPHONE            RESIDENCE
# 1                                   FORCIBLE ENTRY            RESIDENCE
# 2  AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST            RESIDENCE
# 3                                      TO PROPERTY                OTHER
# 4                                           SIMPLE               STREET
#
# ...

# %% [markdown]
# Use subsetting and grouping to show how the frequency of crime is distributed within Months, Days, Seasons with the most crime record and what crimes are highest and lowest?

# %%
subset_data = chicago_df[['Month', 'Day', 'Season', 'Description']]

# Group by Month, Day, and Season and count the occurrences of each crime
crime_counts = subset_data.groupby(['Month', 'Day', 'Season', 'Description']).size().reset_index(name='Frequency')
crime_counts
# Out:
#      Month  Day  Season                     Description  Frequency
# 0        1    1  Winter           AGGRAVATED OF A CHILD          1
# 1        1    1  Winter   AGGRAVATED: OTHER DANG WEAPON          1
# 2        1    1  Winter         DOMESTIC BATTERY SIMPLE          1
# 3        1    1  Winter                   FROM BUILDING          1
# 4        1    2  Winter         DOMESTIC BATTERY SIMPLE          1
# ..     ...  ...     ...                             ...        ...
# 924     12   29  Winter                  $500 AND UNDER          1
# 925     12   30  Winter                  $500 AND UNDER          1
# 926     12   30  Winter                  FORCIBLE ENTRY          1
# 927     12   31  Winter   ARMED: OTHER DANGEROUS WEAPON          1
# 928     12   31  Winter  ATTEMPT: ARMED-KNIFE/CUT INSTR          1
#
# [929 rows x 5 columns]

# %%
# Find the month, day, and season with the most crime records
most_crime_month = crime_counts.groupby('Month')['Frequency'].sum().idxmax()
most_crime_day = crime_counts.groupby('Day')['Frequency'].sum().idxmax()
most_crime_season = crime_counts.groupby('Season')['Frequency'].sum().idxmax()

# %%
print("Month with the most crime records:", most_crime_month)
print("Day with the most crime records:", most_crime_day)
print("Season with the most crime records:", most_crime_season)

# Find the most and least common crimes
crime_freq_summary = crime_counts.groupby('Description')['Frequency'].sum().reset_index()
most_common_crime = crime_freq_summary.loc[crime_freq_summary['Frequency'].idxmax()]
least_common_crime = crime_freq_summary.loc[crime_freq_summary['Frequency'].idxmin()]

print("Most common crime:", most_common_crime['Description'], "with", most_common_crime['Frequency'], "occurrences")
print("Least common crime:", least_common_crime['Description'], "with", least_common_crime['Frequency'], "occurrences")
# Out:
# Month with the most crime records: 10
# Day with the most crime records: 2
# Season with the most crime records: Fall
# Most common crime: SIMPLE with 124 occurrences
# Least common crime: AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY with 1 occurrences

# %% [markdown]
# According to location description, where does crime hapen the most?

# %%
# Top 10 locations with the most crime
most_crime_location = chicago_df['Location Description'].value_counts().head(10)
most_crime_location
# Out:
# STREET                            276
# RESIDENCE                         168
# APARTMENT                         126
# SIDEWALK                           92
# OTHER                              38
# PARKING LOT/GARAGE(NON.RESID.)     26
# SCHOOL, PUBLIC, BUILDING           22
# SMALL RETAIL STORE                 20
# ALLEY                              16
# RESIDENCE PORCH/HALLWAY            15
# Name: Location Description, dtype: int64

# %% [markdown]
# Did the Types of crime change as years go by? if yes/no. let the data show the insight.

# %%
crime_per_year = chicago_df.groupby(['Description', 'Year']).size()
crime_per_year = crime_per_year.reset_index(name='Frequency')
crime_per_year
# Out:
#                         Description  Year  Frequency
# 0                    $500 AND UNDER  2001          7
# 1                    $500 AND UNDER  2002          6
# 2                    $500 AND UNDER  2003          6
# 3                    $500 AND UNDER  2004          5
# 4                    $500 AND UNDER  2005          3
# ..                              ...   ...        ...
# 498  UNLAWFUL USE OTHER DANG WEAPON  2002          1
# 499  UNLAWFUL USE OTHER DANG WEAPON  2008          1
# 500       VEHICLE TITLE/REG OFFENSE  2019          1
# 501             VEHICULAR HIJACKING  2010          1
# 502     VIOLATE ORDER OF PROTECTION  2005          1
#
# [503 rows x 3 columns]

# %% [markdown]
# YES, the types of crime change as years
